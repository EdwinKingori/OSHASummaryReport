# %%
import pandas as pd

# %% [markdown]
# Import the needed datasets

# %%
found_vpp = pd.read_excel("found_vpp.xlsx")
found_vpp.head()
# Out:
#                company_name        establishment_name           city state  \
# 0             Marker, Inc.               marker, inc.  bellefontaine    oh
# 1             Marker, Inc.               marker, inc.  bellefontaine    oh
# 2              Marker, Inc.              marker, inc.  bellefontaine    oh
# 3  Chapel Electric Co., LLC  chapel electric co., llc         dayton    oh
# 4  Chapel Electric Co., LLC  chapel electric co., llc         dayton    oh
#
#    naics_code                 site_name           City State     NAICs  \
# 0      236220              marker, inc.  bellefontaine    oh  236220.0
# 1      236220              marker, inc.  bellefontaine    oh  236220.0
# 2      236220              marker, inc.  bellefontaine    oh  236220.0
# 3      238210  chapel electric co., llc         dayton    oh  238210.0
# 4      238210  chapel electric co., llc         dayton    oh  238210.0
#
#    annual_average_employees  ...  total_injuries  total_poisonings  \
# ...

# %%
vpp_sites_df = pd.read_excel(
    "/home/eddy/Documents/OSHA_Injury_data_analysis/Milestone 2(revised)/Milestone 2/vpp_sites.xlsx")
vpp_sites_df.head()
# Out:
#    year_joined    establishment_name_vpp      city_vpp state_vpp  \
# 0         2015        shermco industries        Irving        TX
# 1         2015  southwire florence plant      Florence        AL
# 2         2015  southwire florence plant      Florence        AL
# 3         2015  southwire florence plant      Florence        AL
# 4         2018             ge healthcare   Westborough        MA
#
#              company_name        establishment_name  city_merged state_merged  \
# 0      Shermco Industries        shermco industries       Irving           TX
# 1  Southwire Company, LLC  southwire florence plant     Florence           AL
# 2       Southwire Company  southwire florence plant     Florence           AL
# 3  Southwire Company. LLC  southwire florence plant     Florence           AL
# 4           GE Healthcare             ge healthcare  Westborough           MA
#
#    naics_code  annual_average_employees  ...  total_djtr_days  total_injuries  \
# ...

# %%
recertified_sites_df = pd.read_excel(
    "Milestone 2(revised)/Milestone 2/recert_results.xlsx")
recertified_sites_df.head()
# Out:
#    year_recertified  year_filing_for  \
# 0              2016             2018
# 1              2022             2021
# 2              2017             2016
# 3              2017             2017
# 4              2018             2016
#
#                    establishment_name_recert     city_vpp state_vpp  \
# 0                      albemarle corporation  baton rouge        la
# 1                               altuglas llc      Bristol        PA
# 2  american buildings company south division      Eufaula        AL
# 3  american buildings company south division      Eufaula        AL
# 4                 amvac chemical corporation      Marsing        ID
#
#           company_name                         establishment_name  \
# 0                  NaN                      albemarle corporation
# 1              Trinseo                               altuglas llc
# 2    Nucor Corporation  american buildings company south division
# ...

# %%
common_names = found_vpp['establishment_name'].isin(
    vpp_sites_df['establishment_name_vpp'])

filtered_df = found_vpp [~common_names]

filtered_df.to_excel("filtered_file.xlsx", index=False)

# %%
common_names_recertified = found_vpp['establishment_name'].isin(
    recertified_sites_df['establishment_name_recert'])

filtered_df = found_vpp[~common_names_recertified]

filtered_df.to_excel("filtered_recert(recertified).xlsx", index=False)
